# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Data Validation
# Describe the validation tasks you performed and what you found. Have you made any changes to the data to enable further analysis? Remember to describe what you did for every column in the data.
#
# *Write your description here*

# %% [markdown]
# ## Data Discovery and Visualization
# Describe what you found in the analysis and how the visualizations answer the customer questions in the project brief. In your description you should:
# - Include at least two different data visualizations to demonstrate the characteristics of single variables
# - Include at least one data visualization to demonstrate the relationship between two or more variables
# - Describe how your analysis has answered the business questions in the project brief
#
# *Write your description here*

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam

# %% [markdown]
# ## **Data Validation**
# ##
# -Claim ID
#
# Every data point in the Claim ID column follows the criteria of being an unique identifier.
# To simplify the data in this column, I replaced the 'Claim ID' with 'ClaimID' by using the excel formula 'REPLACE' twice to remove the zeroes that are repeated accross the column. I then proceeded to delete the first 2 columns in order to use the new 'ClaimID' as the new unique identifier.
#
# ![image](image.png)
#
#
#
# -Time to Close
#
# The time to close data point associated with the ClaimID 2019.0079 was '-57' which has been changed to '57'as the number of days that it takes for the claim to close needs to be an absolute value to match the criteria.
#
#
# -Claim Amount
#
# To remove the currency symbol from the 'Claim Amount' column, the 'Replace' formula was used again to remove the first 2 characters from each string.
# To remove the punctuation on the Claim Amount, the 'Find and Replace' function was used to remove the commas within the integer and replace them with nothing, which had the same effect as deleting it.This also removed the full stops used for decimal placements in the column
#
# ![image-2](image-2.png)
#
# -Amount Paid
#
# The 'Amount Paid' column followed the character criteria and required no changes/modifications.
#
# -Location
#
# The 'Location' column followed the character criteria and required no changes/modifications.
#
# -Individuals on Claim
#
# The 'Individuals On Claim' column followed the character criteria and required no changes/modifications.
#
# -Linked Cases
#
# The 'Linked Cases' column followed the character criteria and required no changes/modifications.
#
# -Cause
#
# To replace the empty cells with 'unknown', the replace tool was used again to modify the data points in the 'Cause' column to fit the criteria.
#
# A picture of a section of the updated data set has been attached below in order to show the updated cells.
#
# ![image-3](image-3.png)

# %% [markdown]
# # Data Discovery & Visualisation
# #
#
# -How does the number of claims differ across locations?
#
# ![image-4](image-4.png)
#
# There are 4 locations within the data set where claims where made. Sao Luis is the location with the highest number of claims(30), Recife with 25, Fortaleza with 22 and Natal has the lowest number of claims with 21. This gives a total of 98 claims against Vivendo.
#
# -What is the distribution of time to close claims?
# ![image-10](image-10.png)
#
# The histogram above shows that most of the cases were closed under 2400 days, with 2 outliers at 2997 and 3591 days. The most common ranges for cases to close where 200-400 days and 400-600 days with 16 cases each. This could possibly suggest that the legal team should aim to close future cases between 200-600 days.
#
# -How does the average time to close claims differ by location?
#
# ![image-11](image-11.png)
#
# The boxplots above display the distribution of the closing times per location with a line across them portraying the city's average.  Sao Luis has the highest average closing time at 1030 days and also has the highest IQR of 1405, which contributes to the fact Sao Luis doesn't have outliers. The other cities have 2-3 outliers with averages between 580-860 days. Their IQRs range between 440-590 suggesting Sao Luis has the most inconsistent data which in turn implies that the legal team should focus more on cases in Sao Luis. Further analysis should be carried using cases from Sao Luis in order to determine if there are significant patterns that are yet to be addressed.
